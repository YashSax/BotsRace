# %%
import matplotlib.pyplot as plt
import pickle

with open("./solution_out", "rb") as f:
    data = pickle.load(f)

# %%
plt.figure(figsize=(10, 10))
plt.xlabel("Timestep")
# plt.plot(data["smoothed_angles"], label="smoothed angles")
# plt.plot(data["unsmoothed_angles"], label="unsmoothed angles")

plt.plot(data["target_angle"], label="target angle")
plt.plot(data["unsmoothed_angles"], label="actual angle")
plt.plot(data["ps"], label="ps")

# for k in data:
#     if k in ["is"]:
#         continue
#     plt.plot(data[k][100:], label=k)
plt.legend()

# %%
plt.figure(figsize=(20, 10))
plt.xlabel("Timestep")

plt.plot(data["tops"], label="tops")
plt.plot(data["bottoms"], label="bottoms")
plt.plot(data["lefts"], label="lefts")
plt.plot(data["rights"], label="rights")

plt.legend()
