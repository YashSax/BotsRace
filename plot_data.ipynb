# %%
import matplotlib.pyplot as plt
import pickle

with open("./solution_out", "rb") as f:
    data = pickle.load(f)

# %%
plt.figure(figsize=(10, 10))
plt.xlabel("Timestep")
plt.plot(data["target_angle"], label="target angle")
plt.plot(data["corrections"], label="correction")
# for k in data:
#     if k in ["corrections"]:
#         continue
#     plt.plot(data[k][100:], label=k)
plt.legend()
